# %%
import requests
import pandas as pd


def get_places(api_key, place_type, location, radius=1500):
    """
    Fetches places of a specific type within a given radius from a location using Google Places API.
    
    :param api_key: Your Google Places API key
    :param place_type: Type of place (e.g., grocery_or_supermarket, pharmacy, gym)
    :param location: Latitude,Longitude of the center point
    :param radius: Radius to search within (in meters)
    :return: DataFrame of places with name, address, rating, and location
    """
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "key": api_key,
        "location": location,
        "radius": radius,
        "type": place_type
    }
    response = requests.get(url, params=params)
    data = response.json()

    # Extract relevant details
    places = []
    for place in data.get('results', []):
        places.append({
            "Name": place.get('name'),
            "Address": place.get('vicinity'),
            "Rating": place.get('rating', 'N/A'),
            "Location": place.get('geometry', {}).get('location', {})
        })

    return pd.DataFrame(places)

schools = ["school", "preschool", "primary_school", "secondary_school", "university"]
food = ['restaurant','coffee_shop','cafe']
health = ['drugstore', 'pharmacy', 'dental_clinic', 'dentist', 'doctor', 'hospital']
undesirable = ['fire_station']
transport = ['airport', 'bus_station', 'bus_stop', 'international_airport', 'train_station', 'transit_station', 'subway_station']
types = ["supermarket", "pharmacy", "gym"] + schools + food + health + undesirable + transport 

def prepare_location_data(api_key, center_location, place_types=types):

    '''
        creates a dictionary of all the desired/undesired amenities/locations in a geographic location
    '''
    
    location_data = {}
    
    for place_type in place_types:
        df = get_places(api_key, place_type, center_location)
        coords = [f"{row['Location']['lat']},{row['Location']['lng']}" 
                  for _, row in df.iterrows() 
                  if 'lat' in row['Location'] and 'lng' in row['Location']]
        location_data[place_type] = coords
    
    return location_data

# %%
# Example Usage
api_key = "AIzaSyCaOWXoABSdgWZYGCRlEiAGyRnHtuha_D0"
location = "47.6234,-122.3387"  # Latitude, Longitude of South Lake Union

all_places = []
for place_type in types:
    df = get_places(api_key, place_type, location)
    df['Type'] = place_type
    all_places.append(df)

places_data = pd.concat(all_places, ignore_index=True)

# %%
pd.set_option('display.max_rows', None)
places_data
# Out:
#                                                   Name  \
# 0                                   Whole Foods Market
# 1                                              Safeway
# 2                                         Pike Grocery
# 3                                      Belltown Market
# 4                                     Belltown Grocery
# 5                                      Ethioblue Store
# 6                              H Mart Downtown Seattle
# 7                                         QFC Pharmacy
# 8                                         QFC Pharmacy
# 9                                Banfield Pet Hospital
# 10                                    Safeway Pharmacy
# 11                                        CVS Pharmacy
# 12                                           Walgreens
# 13                                  Walgreens Pharmacy
# 14   UW Medicine Outpatient Pharmacy at South Lake ...
# 15                                  Walgreens Pharmacy
# 16                                             Capsule
# 17                                         Reeve Shima
# 18                   Kelley-Ross Capitol Hill Pharmacy
# 19                                        CVS Pharmacy
# 20                                     RPh Connect LLC
# 21                                      Brim Pauline M
# 22                                     24 Hour Fitness
# 23                                      Urban Yoga Spa
# 24                                    PRO Club Seattle
# 25                                    Breathe Hot Yoga
# 26                                         ZUM Fitness
# 27                               Seattle Athletic Club
# 28                           Pacific Northwest Fitness
# 29                       CorePower Yoga - Capitol Hill
# 30                                       TRIBE Fitness
# 31                                         Axtion Club
# 32                                        Flow Fitness
# 33                                          Pure Barre
# 34                                Orangetheory Fitness
# 35         GO PT (Physical Therapy) - South Lake Union
# 36                Transform 180 Fitness - Belltown Gym
# 37                                Orangetheory Fitness
# 38                                      CrossFit Felix
# 39                                       Demco Fitness
# 40                                        Club Pilates
# 41                                Orangetheory Fitness
# 42                                   The Center School
# 43                 Bright Horizons at South Lake Union
# 44                         Bright Horizons at West 8th
# 45                                The Northwest School
# 46                                Spruce Street School
# 47                          John Hay Elementary School
# 48                            Pacific First Montessori
# 49                                  Seattle KinderCare
# 50             Kiddie Academy of Seattle at Queen Anne
# 51                                      In-depth Scuba
# 52                    International Montessori Academy
# 53                                       College Match
# 54                   Theama Spiritual Community Center
# 55              The Downtown School: A Lakeside School
# 56                                eLearning Department
# 57                         Terrence Rosnagle Guitarist
# 58                 Diamond Way Buddhist Center Seattle
# 59                               Harvard Avenue School
# 60                                         SkipperBudz
# 61                               Taylor Robinson Music
# 62                                             Seattle
# 63    Holiday Inn Express & Suites Seattle-City Center
# 64   Holiday Inn Seattle Downtown - Lake Union, an ...
# 65     Four Points by Sheraton Downtown Seattle Center
# 66           Residence Inn Seattle Downtown/Lake Union
# 67   Travelodge by Wyndham Seattle By The Space Needle
# 68             Denny Park Hotel (Formerly Pan Pacific)
# 69   La Quinta Inn & Suites by Wyndham Seattle Down...
# 70               Hampton Inn & Suites Seattle-Downtown
# 71                  Hotel Five - A Staypineapple Hotel
# 72                                   The Maxwell Hotel
# 73             Silver Cloud Hotel - Seattle Lake Union
# 74                                           Hotel Max
# 75                                     Warwick Seattle
# 76                                  The Westin Seattle
# 77                                        Belltown Inn
# 78                                    Hyatt at Olive 8
# 79                                 The Paramount Hotel
# 80                                 Grand Hyatt Seattle
# 81                                    Downtown Seattle
# 82                                Spruce Street School
# 83                          John Hay Elementary School
# 84                    International Montessori Academy
# 85                               John Hay Loading Dock
# 86                                   The Center School
# 87                                The Northwest School
# 88              The Downtown School: A Lakeside School
# 89                              Fusion Academy Seattle
# 90                              Interagency Academy QA
# 91                         Cornish College of the Arts
# 92                                   Hillsdale College
# 93                                Medtap International
# 94                                             Stamlab
# 95         The Seattle School of Theology & Psychology
# 96                     Northeastern University Seattle
# 97                            Department of Immunology
# 98                         225 Northeastern University
# 99                         Horizon College of Ministry
# 100  Cornish College of the Arts - Raisbeck Perform...
# 101                         City University of Seattle
# 102                         Antioch University Seattle
# 103       Seattle Central College Continuing Education
# 104                                      College Match
# 105           Cornish College of the Arts - Kerry Hall
# 106                             University Of Wash Uro
# 107                             Insightful Corporation
# 108                            Seattle Central College
# 109                          eLearning & Continuing Ed
# 110           Seattle Central College Student Services
# 111                   Buca di Beppo Italian Restaurant
# 112                                             TIDAL+
# 113                Portage Bay Cafe - South Lake Union
# 114                                   Daniel's Broiler
# 115                            Cactus South Lake Union
# 116                                     Palace Kitchen
# 117                               Serious Pie Downtown
# 118  The 5 Point Cafe | 24 Hour Legendary Dive Bar ...
# 119                                  Barolo Ristorante
# 120                             Dimitriou's Jazz Alley
# 121                             The Cheesecake Factory
# 122                                Lunchbox Laboratory
# 123                                               Lola
# 124                                  Top Pot Doughnuts
# 125                    Toulouse Petit Kitchen & Lounge
# 126                                      Shiro's Sushi
# 127                                 Pike Place Chowder
# 128                                     Umi Sake House
# 129                                      Relish Bistro
# 130                                             Subway
# 131                                            Seattle
# 132   Holiday Inn Express & Suites Seattle-City Center
# 133  Holiday Inn Seattle Downtown - Lake Union, an ...
# 134    Four Points by Sheraton Downtown Seattle Center
# 135          Residence Inn Seattle Downtown/Lake Union
# 136  Travelodge by Wyndham Seattle By The Space Needle
# 137            Denny Park Hotel (Formerly Pan Pacific)
# 138  La Quinta Inn & Suites by Wyndham Seattle Down...
# 139              Hampton Inn & Suites Seattle-Downtown
# 140                 Hotel Five - A Staypineapple Hotel
# 141                                  The Maxwell Hotel
# 142            Silver Cloud Hotel - Seattle Lake Union
# 143                                          Hotel Max
# 144                                    Warwick Seattle
# 145                                 The Westin Seattle
# 146                                       Belltown Inn
# 147                                   Hyatt at Olive 8
# 148                                The Paramount Hotel
# 149                                Grand Hyatt Seattle
# 150                                   Downtown Seattle
# 151                Portage Bay Cafe - South Lake Union
# 152                                  Top Pot Doughnuts
# 153                                          FareStart
# 154            Metropolitan Market Queen Anne (Uptown)
# 155   Tutta Bella Neapolitan Pizzeria - Seattle at REN
# 156                                 Citizen Collective
# 157                                  Top Pot Doughnuts
# 158                                          Starbucks
# 159                                     Deli Shez Cafe
# 160                       Espresso Vivace Capitol Hill
# 161                   Espresso Vivace South Lake Union
# 162                         Uptown Espresso - Belltown
# 163                              Einstein Bros. Bagels
# 164                                 Street Bean Coffee
# 165                                          Starbucks
# 166                                         Bacco Cafe
# 167                     Caffe Ladro - Lower Queen Anne
# 168                                          Starbucks
# 169                                          Starbucks
# 170                             Caffe Umbria Olive Way
# 171                                          Walgreens
# 172                                       QFC Pharmacy
# 173                                       QFC Pharmacy
# 174                                                CVS
# 175                                   Safeway Pharmacy
# 176                                                CVS
# 177                                       QFC Pharmacy
# 178                                       QFC Pharmacy
# 179                              Banfield Pet Hospital
# 180                                   Safeway Pharmacy
# 181                                       CVS Pharmacy
# 182                                          Walgreens
# 183                                 Walgreens Pharmacy
# 184  UW Medicine Outpatient Pharmacy at South Lake ...
# 185                                 Walgreens Pharmacy
# 186                                            Capsule
# 187                                        Reeve Shima
# 188                  Kelley-Ross Capitol Hill Pharmacy
# 189                                       CVS Pharmacy
# 190                                    RPh Connect LLC
# 191                                     Brim Pauline M
# 192                                            Seattle
# 193   Holiday Inn Express & Suites Seattle-City Center
# 194  Holiday Inn Seattle Downtown - Lake Union, an ...
# 195    Four Points by Sheraton Downtown Seattle Center
# 196          Residence Inn Seattle Downtown/Lake Union
# 197  Travelodge by Wyndham Seattle By The Space Needle
# 198            Denny Park Hotel (Formerly Pan Pacific)
# 199  La Quinta Inn & Suites by Wyndham Seattle Down...
# 200              Hampton Inn & Suites Seattle-Downtown
# 201                 Hotel Five - A Staypineapple Hotel
# 202                                  The Maxwell Hotel
# 203            Silver Cloud Hotel - Seattle Lake Union
# 204                                          Hotel Max
# 205                                    Warwick Seattle
# 206                                 The Westin Seattle
# 207                                       Belltown Inn
# 208                                   Hyatt at Olive 8
# 209                                The Paramount Hotel
# 210                                Grand Hyatt Seattle
# 211                                   Downtown Seattle
# 293  La Quinta Inn & Suites by Wyndham Seattle Down...
# 294              Hampton Inn & Suites Seattle-Downtown
# 295                 Hotel Five - A Staypineapple Hotel
# 296                                  The Maxwell Hotel
# 297            Silver Cloud Hotel - Seattle Lake Union
# 298                                          Hotel Max
# 299                                    Warwick Seattle
# 300                                 The Westin Seattle
# 301                                       Belltown Inn
# 302                                   Hyatt at Olive 8
# 303                                The Paramount Hotel
# 304                                Grand Hyatt Seattle
# 305                                   Downtown Seattle
# 306                                            Seattle
# 307   Holiday Inn Express & Suites Seattle-City Center
# 308  Holiday Inn Seattle Downtown - Lake Union, an ...
# 309    Four Points by Sheraton Downtown Seattle Center
# 310          Residence Inn Seattle Downtown/Lake Union
# 311  Travelodge by Wyndham Seattle By The Space Needle
# 312            Denny Park Hotel (Formerly Pan Pacific)
# 313  La Quinta Inn & Suites by Wyndham Seattle Down...
# 314              Hampton Inn & Suites Seattle-Downtown
# 315                 Hotel Five - A Staypineapple Hotel
# 316                                  The Maxwell Hotel
# 317            Silver Cloud Hotel - Seattle Lake Union
# 318                                          Hotel Max
# 319                                    Warwick Seattle
# 320                                 The Westin Seattle
# 321                                       Belltown Inn
# 322                                   Hyatt at Olive 8
# 323                                The Paramount Hotel
# 324                                Grand Hyatt Seattle
# 325                                   Downtown Seattle
# 326                            Seattle Center Monorail
# 327                         Westlake Ave N & Mercer St
# 328                       Westlake Ave N & Harrison St
# 329                           Dexter Ave N & Mercer St
# 330                         Valley St & Fairview Ave N
# 331                            Dexter Ave N & Aloha St
# 332                           Denny Way & Westlake Ave
# 333                           Dexter Ave N & Denny Way
# 334                             Westlake Ave & 9th Ave
# 335                          Fairview Ave N & Aloha St
# 336                          5th Ave N & Republican St
# 337                               5th Ave N & Broad St
# 338                         Aurora Ave N & Prospect St
# 339                       Westlake Ave N & Highland Dr
# 340                         Taylor Ave N & Prospect St
# 341                              5th Ave N & Denny Way
# 342                                   Westlake And 7th
# 343                                  Westlake & Mercer
# 344                                     Terry & Mercer
# 345                       Westlake Ave N & Harrison St
#
#                                                Address Rating  \
# 0                        2210 Westlake Avenue, Seattle    4.3
# 1                         516 1st Avenue West, Seattle    3.9
# 2                            1011 Pike Street, Seattle    3.8
# 3                             2424 1st Avenue, Seattle    4.0
# 4                             2221 3rd Avenue, Seattle    3.9
# 5                             815 Pike Street, Seattle    3.9
# 6                             1601 2nd Avenue, Seattle    4.4
# 7                           500 Mercer Street, Seattle    3.7
# 8                        417 Broadway East #2, Seattle      4
# 9                        512 1st Avenue North, Seattle    3.7
# 10                        516 1st Avenue West, Seattle    3.3
# 11                        503 Westlake Avenue, Seattle    3.2
# 12                          951 Mercer Street, Seattle    2.6
# 13                          951 Mercer Street, Seattle    3.7
# 14   750 Republican Street building f 1st floor, Se...    3.7
# 15                              566 Denny Way, Seattle      2
# 16                  2033 6th Avenue Suite 120, Seattle    3.8
# 17                   100 West Harrison Street, Seattle    N/A
# 18            400 East Pine Street Suite 100B, Seattle    4.9
# 19                531 Queen Anne Avenue North, Seattle    2.8
# 20              16 West Harrison Street # 203, Seattle    N/A
# 21     U.S. Bank Centre, 1420 5th Avenue #375, Seattle    N/A
# 219                   720 Olive Way suite 860, Seattle      5
# 220                             509 Olive Way, Seattle    4.9
# 221                       509 Olive Way #1524, Seattle    N/A
# 222                       509 Olive Way #1043, Seattle    4.7
# 223                        509 Olive Way #750, Seattle    N/A
# 224                       509 Olive Way # 824, Seattle    4.9
# 225                        509 Olive Way #750, Seattle    4.8
# 226                        509 Olive Way #620, Seattle    N/A
# 227                             509 Olive Way, Seattle    N/A
# 228                      509 Olive Way # 1607, Seattle    N/A
# 229                       509 Olive Way #1556, Seattle      5
# 230                       509 Olive Way #1520, Seattle    4.9
# 231                        509 Olive Way #645, Seattle    4.5
# 232                  825 Eastlake Avenue East, Seattle    N/A
# 233                  825 Eastlake Avenue East, Seattle    N/A
# 234                  825 Eastlake Avenue East, Seattle    N/A
# 235                  825 Eastlake Avenue East, Seattle    N/A
# 236                             511 Olive Way, Seattle      4
# 237                  825 Eastlake Avenue East, Seattle    N/A
# 238                     750 Republican Street, Seattle    N/A
# 239                  825 Eastlake Avenue East, Seattle    N/A
# 240                  825 Eastlake Avenue East, Seattle      5
# 241                  825 Eastlake Avenue East, Seattle      5
# 242                        509 Olive Way #817, Seattle    3.2
# 243                      509 Olive Way # 1607, Seattle    N/A
# 244                  825 Eastlake Avenue East, Seattle    N/A
# 245                  825 Eastlake Avenue East, Seattle    N/A
# 246                 1505 Westlake Avenue #400, Seattle    3.8
# 247            1505 Westlake Avenue Suite 400, Seattle      5
# 248                  825 Eastlake Avenue East, Seattle    N/A
# 249        501 Eastlake Avenue East Suite 300, Seattle    N/A
# 250         501 Eastlake Avenue East UNIT 400, Seattle    N/A
# 251  Jack R. Mac Donald Building, 1900 9th Avenue C...    N/A
# 252                         1354 Aloha Street, Seattle    4.3
# 253                        509 Olive Way #817, Seattle    3.2
# 254                 1633 Westlake Avenue #170, Seattle    N/A
# 255                             509 Olive Way, Seattle    4.9
# 256                 1700 Westlake Avenue #700, Seattle    3.3
# 257                        1209 Valley Street, Seattle    4.3
# 258                 2505 2nd Avenue Suite 200, Seattle    N/A
# 259                 2505 2nd Avenue Suite 200, Seattle    N/A
# 260                  509 Olive Way Suites 900, Seattle    2.8
# 261                       509 Olive Way #1055, Seattle    N/A
# 262                         1334 Terry Avenue, Seattle    2.8
# 263                      2025 1st Avenue #720, Seattle      5
# 264            1000 Dexter Avenue North #320b, Seattle    4.3
# 265             1101 Dexter Avenue North #105, Seattle      5
# 266                     820 Yale Avenue North, Seattle    4.6
# 267                  825 Eastlake Avenue East, Seattle    N/A
# 268                 1500 Westlake Avenue #120, Seattle      5
# 269                         1334 Terry Avenue, Seattle    N/A
# 270         133 Queen Anne Avenue North STE A, Seattle      5
# 271                           2320 4th Avenue, Seattle    4.6
# 272                            110 Lee Street, Seattle    5.0
# 273                       950 Westlake Avenue, Seattle    4.7
# 274                 1325 Fairview Avenue East, Seattle    4.8
# 275                                      United States      3
# 276                                      United States    N/A
# 277                                      United States      5
# 278                                      United States    N/A
# 279                                      United States      3
# 280                                      United States    4.4
# 281                                      United States    N/A
# 282                                      United States    4.3
# 283                                      United States      4
# 284                                      United States    3.5
# 285                                      United States      2
# 286                                            Seattle    N/A
# 287                      226 7th Avenue North, Seattle    3.9
# 288                   211 Dexter Avenue North, Seattle    3.9
# 289                            601 Roy Street, Seattle      4
# 290                 800 Fairview Avenue North, Seattle    4.2
# 291                      200 6th Avenue North, Seattle    3.3
# 292                         2125 Terry Avenue, Seattle    4.5
# 293                           2224 8th Avenue, Seattle    4.1
# 294                      700 5th Avenue North, Seattle    4.1
# 295                           2200 5th Avenue, Seattle    4.4
# 296                            300 Roy Street, Seattle    4.6
# 297                1150 Fairview Avenue North, Seattle    4.5
# 298                        620 Stewart Street, Seattle    4.1
# 299                         401 Lenora Street, Seattle    3.8
# 300                           1900 5th Avenue, Seattle    4.2
# 301                           2301 3rd Avenue, Seattle    4.3
# 302                           1635 8th Avenue, Seattle    4.5
# 303                           724 Pine Street, Seattle    4.5
# 304                           721 Pine Street, Seattle    4.5
# 305                                            Seattle    N/A
# 306                                            Seattle    N/A
# 307                      226 7th Avenue North, Seattle    3.9
# 308                   211 Dexter Avenue North, Seattle    3.9
# 309                            601 Roy Street, Seattle      4
# 310                 800 Fairview Avenue North, Seattle    4.2
# 311                      200 6th Avenue North, Seattle    3.3
# 312                         2125 Terry Avenue, Seattle    4.5
# 313                           2224 8th Avenue, Seattle    4.1
# 314                      700 5th Avenue North, Seattle    4.1
# 315                           2200 5th Avenue, Seattle    4.4
# 316                            300 Roy Street, Seattle    4.6
# 317                1150 Fairview Avenue North, Seattle    4.5
# 318                        620 Stewart Street, Seattle    4.1
# 319                         401 Lenora Street, Seattle    3.8
# 320                           1900 5th Avenue, Seattle    4.2
# 321                           2301 3rd Avenue, Seattle    4.3
# 322                           1635 8th Avenue, Seattle    4.5
# 323                           724 Pine Street, Seattle    4.5
# 324                           721 Pine Street, Seattle    4.5
# 325                                            Seattle    N/A
# 326                         370 Thomas Street, Seattle    4.4
# 327                                      United States    N/A
# 328                                      United States    N/A
# 329                                      United States    N/A
# 330                                      United States    N/A
# 331                                      United States    N/A
# 332                                      United States    N/A
# 333                                      United States    N/A
# 334                                      United States    N/A
# 335                                      United States      3
# 336                                      United States      5
# 337                                      United States    N/A
# 338                                      United States    N/A
# 339                                      United States    N/A
# 340                                      United States    N/A
# 341                                      United States    N/A
# 342                                      United States    N/A
# 343                                      United States    4.4
# 344                                      United States      5
# 345                                      United States      5
#
#                                             Location                   Type
# 0           {'lat': 47.6183573, 'lng': -122.3380162}            supermarket
# 1     {'lat': 47.62359989999999, 'lng': -122.357705}            supermarket
# 2    {'lat': 47.61323120000001, 'lng': -122.3289985}            supermarket
# 3    {'lat': 47.61473669999999, 'lng': -122.3485197}            supermarket
# 4           {'lat': 47.6142073, 'lng': -122.3444919}            supermarket
# 5    {'lat': 47.61197310000001, 'lng': -122.3319248}            supermarket
# 6             {'lat': 47.61027, 'lng': -122.3402051}            supermarket
# 7           {'lat': 47.6249417, 'lng': -122.3471343}               pharmacy
# 8             {'lat': 47.622597, 'lng': -122.321378}               pharmacy
# 9           {'lat': 47.6238262, 'lng': -122.3550643}               pharmacy
# 10          {'lat': 47.6235726, 'lng': -122.3577979}               pharmacy
# 11          {'lat': 47.6233739, 'lng': -122.3388013}               pharmacy
# 12    {'lat': 47.62437319999999, 'lng': -122.338026}               pharmacy
# 13    {'lat': 47.62437449999999, 'lng': -122.338024}               pharmacy
# 14          {'lat': 47.6236533, 'lng': -122.3419756}               pharmacy
# 15          {'lat': 47.6188334, 'lng': -122.3455122}               pharmacy
# 16           {'lat': 47.614592, 'lng': -122.3391944}               pharmacy
# 17   {'lat': 47.62297249999999, 'lng': -122.3584513}               pharmacy
# 18          {'lat': 47.6154336, 'lng': -122.3264714}               pharmacy
# 19          {'lat': 47.6244603, 'lng': -122.3568817}               pharmacy
# 20           {'lat': 47.622276, 'lng': -122.3576943}               pharmacy
# 21           {'lat': 47.6106515, 'lng': -122.334796}               pharmacy
# 22           {'lat': 47.6180661, 'lng': -122.330962}                    gym
# 23          {'lat': 47.6125702, 'lng': -122.3387332}                    gym
# 24          {'lat': 47.6235008, 'lng': -122.3295425}                    gym
# 25          {'lat': 47.6183511, 'lng': -122.3486867}                    gym
# 26          {'lat': 47.6137368, 'lng': -122.3358142}                    gym
# 27          {'lat': 47.6108856, 'lng': -122.3440399}                    gym
# 28            {'lat': 47.622867, 'lng': -122.321286}                    gym
# 29           {'lat': 47.623323, 'lng': -122.3212249}                    gym
# 30    {'lat': 47.62457099999999, 'lng': -122.320699}                    gym
# 31           {'lat': 47.616192, 'lng': -122.3488698}                    gym
# 32            {'lat': 47.62137, 'lng': -122.3374609}                    gym
# 33          {'lat': 47.6250733, 'lng': -122.3472849}                    gym
# 34   {'lat': 47.62507420000001, 'lng': -122.3473012}                    gym
# 35   {'lat': 47.61985459999999, 'lng': -122.3306425}                    gym
# 36          {'lat': 47.6182348, 'lng': -122.3451497}                    gym
# 37   {'lat': 47.61633639999999, 'lng': -122.3432044}                    gym
# 38   {'lat': 47.61539459999999, 'lng': -122.3422865}                    gym
# 39          {'lat': 47.6170048, 'lng': -122.3470249}                    gym
# 40            {'lat': 47.618793, 'lng': -122.354506}                    gym
# 41          {'lat': 47.6237215, 'lng': -122.3211592}                    gym
# 42   {'lat': 47.62193509999999, 'lng': -122.3513682}                 school
# 43          {'lat': 47.6239936, 'lng': -122.3308231}                 school
# 44          {'lat': 47.6157711, 'lng': -122.3372282}                 school
# 45          {'lat': 47.6134057, 'lng': -122.3257969}                 school
# 46   {'lat': 47.61688729999999, 'lng': -122.3353145}                 school
# 47          {'lat': 47.6328489, 'lng': -122.3522135}                 school
# 48          {'lat': 47.6103116, 'lng': -122.3350438}                 school
# 49          {'lat': 47.6146137, 'lng': -122.3353332}                 school
# 50            {'lat': 47.626077, 'lng': -122.344596}                 school
# 51          {'lat': 47.6309907, 'lng': -122.3440178}                 school
# 52          {'lat': 47.6197658, 'lng': -122.3228796}                 school
# 53   {'lat': 47.61410189999999, 'lng': -122.3353734}                 school
# 54            {'lat': 47.623374, 'lng': -122.320092}                 school
# 55   {'lat': 47.62002159999999, 'lng': -122.3537193}                 school
# 56          {'lat': 47.6170868, 'lng': -122.3219315}                 school
# 57   {'lat': 47.61452550000001, 'lng': -122.3237231}                 school
# 58          {'lat': 47.6117027, 'lng': -122.3450977}                 school
# 59          {'lat': 47.6200602, 'lng': -122.3224991}                 school
# 60    {'lat': 47.62736690000001, 'lng': -122.340381}                 school
# 61          {'lat': 47.6273781, 'lng': -122.3457516}                 school
# 62          {'lat': 47.6061389, 'lng': -122.3328481}              preschool
# 63          {'lat': 47.6205186, 'lng': -122.3426781}              preschool
# 64             {'lat': 47.62033, 'lng': -122.342822}              preschool
# 65          {'lat': 47.6249635, 'lng': -122.3447049}              preschool
# 66   {'lat': 47.62639619999999, 'lng': -122.3331541}              preschool
# ...
# 141         {'lat': 47.6256677, 'lng': -122.3508744}            coffee_shop
# 142          {'lat': 47.6297061, 'lng': -122.329046}            coffee_shop
# 143  {'lat': 47.61428739999999, 'lng': -122.3367201}            coffee_shop
# 144         {'lat': 47.6139253, 'lng': -122.3407168}            coffee_shop
# 145         {'lat': 47.6136997, 'lng': -122.3381933}            coffee_shop
# 146         {'lat': 47.6146282, 'lng': -122.3451633}            coffee_shop
# 147         {'lat': 47.6138017, 'lng': -122.3341859}            coffee_shop
# 148   {'lat': 47.61314999999999, 'lng': -122.333677}            coffee_shop
# 149         {'lat': 47.6127521, 'lng': -122.3334516}            coffee_shop
# 150         {'lat': 47.6050242, 'lng': -122.3343709}            coffee_shop
# 151           {'lat': 47.621843, 'lng': -122.337419}                   cafe
# 152         {'lat': 47.6151643, 'lng': -122.3412291}                   cafe
# 153         {'lat': 47.6152455, 'lng': -122.3375604}                   cafe
# 154         {'lat': 47.6247988, 'lng': -122.3548324}                   cafe
# 155         {'lat': 47.6182066, 'lng': -122.3337038}                   cafe
# 156  {'lat': 47.62569429999999, 'lng': -122.3459624}                   cafe
# 157         {'lat': 47.6246574, 'lng': -122.3255798}                   cafe
# 158          {'lat': 47.6299782, 'lng': -122.340027}                   cafe
# 159         {'lat': 47.6144399, 'lng': -122.3430862}                   cafe
# 160         {'lat': 47.6237833, 'lng': -122.3206194}                   cafe
# 161         {'lat': 47.6202049, 'lng': -122.3306253}                   cafe
# 162  {'lat': 47.61696569999999, 'lng': -122.3462736}                   cafe
# 163          {'lat': 47.618032, 'lng': -122.3388581}                   cafe
# 164         {'lat': 47.6172573, 'lng': -122.3494879}                   cafe
# 165         {'lat': 47.6229122, 'lng': -122.3368429}                   cafe
# 166  {'lat': 47.61005460000001, 'lng': -122.3413612}                   cafe
# 167          {'lat': 47.625346, 'lng': -122.3565528}                   cafe
# 168         {'lat': 47.6141529, 'lng': -122.3355733}                   cafe
# 169          {'lat': 47.6122153, 'lng': -122.333675}                   cafe
# 170  {'lat': 47.61357859999999, 'lng': -122.3355599}                   cafe
# 171  {'lat': 47.61896029999999, 'lng': -122.3455144}              drugstore
# 172         {'lat': 47.6249417, 'lng': -122.3471343}              drugstore
# 173           {'lat': 47.622597, 'lng': -122.321378}              drugstore
# 174         {'lat': 47.6243004, 'lng': -122.3570503}              drugstore
# 175         {'lat': 47.6235726, 'lng': -122.3577979}              drugstore
# 176         {'lat': 47.6233739, 'lng': -122.3388013}              drugstore
# 177         {'lat': 47.6249417, 'lng': -122.3471343}               pharmacy
# 178           {'lat': 47.622597, 'lng': -122.321378}               pharmacy
# 179         {'lat': 47.6238262, 'lng': -122.3550643}               pharmacy
# 180         {'lat': 47.6235726, 'lng': -122.3577979}               pharmacy
# 181         {'lat': 47.6233739, 'lng': -122.3388013}               pharmacy
# 182   {'lat': 47.62437319999999, 'lng': -122.338026}               pharmacy
# 183   {'lat': 47.62437449999999, 'lng': -122.338024}               pharmacy
# 184         {'lat': 47.6236533, 'lng': -122.3419756}               pharmacy
# 185         {'lat': 47.6188334, 'lng': -122.3455122}               pharmacy
# 186          {'lat': 47.614592, 'lng': -122.3391944}               pharmacy
# 187  {'lat': 47.62297249999999, 'lng': -122.3584513}               pharmacy
# 188         {'lat': 47.6154336, 'lng': -122.3264714}               pharmacy
# 189         {'lat': 47.6244603, 'lng': -122.3568817}               pharmacy
# 190          {'lat': 47.622276, 'lng': -122.3576943}               pharmacy
# 191          {'lat': 47.6106515, 'lng': -122.334796}               pharmacy
# 192         {'lat': 47.6061389, 'lng': -122.3328481}          dental_clinic
# 193         {'lat': 47.6205186, 'lng': -122.3426781}          dental_clinic
# 194            {'lat': 47.62033, 'lng': -122.342822}          dental_clinic
# 195         {'lat': 47.6249635, 'lng': -122.3447049}          dental_clinic
# 196  {'lat': 47.62639619999999, 'lng': -122.3331541}          dental_clinic
# 197         {'lat': 47.6204076, 'lng': -122.3446676}          dental_clinic
# 198           {'lat': 47.618244, 'lng': -122.337408}          dental_clinic
# 199  {'lat': 47.61805649999999, 'lng': -122.3398985}          dental_clinic
# 200         {'lat': 47.6258293, 'lng': -122.3468997}          dental_clinic
# 201  {'lat': 47.61554169999999, 'lng': -122.3418856}          dental_clinic
# 202         {'lat': 47.6256677, 'lng': -122.3508744}          dental_clinic
# 203          {'lat': 47.6297061, 'lng': -122.329046}          dental_clinic
# 204  {'lat': 47.61428739999999, 'lng': -122.3367201}          dental_clinic
# 205         {'lat': 47.6139253, 'lng': -122.3407168}          dental_clinic
# 206         {'lat': 47.6136997, 'lng': -122.3381933}          dental_clinic
# 207         {'lat': 47.6146282, 'lng': -122.3451633}          dental_clinic
# 208         {'lat': 47.6138017, 'lng': -122.3341859}          dental_clinic
# 209   {'lat': 47.61314999999999, 'lng': -122.333677}          dental_clinic
# 210         {'lat': 47.6127521, 'lng': -122.3334516}          dental_clinic
# 211         {'lat': 47.6050242, 'lng': -122.3343709}          dental_clinic
# 212         {'lat': 47.6128525, 'lng': -122.3363899}                dentist
# 213         {'lat': 47.6127468, 'lng': -122.3365653}                dentist
# 214         {'lat': 47.6127468, 'lng': -122.3365653}                dentist
# 215         {'lat': 47.6127468, 'lng': -122.3365653}                dentist
# 216         {'lat': 47.6174577, 'lng': -122.3302018}                dentist
# 217         {'lat': 47.6127599, 'lng': -122.3367057}                dentist
# 218         {'lat': 47.6128181, 'lng': -122.3366665}                dentist
# 219         {'lat': 47.6141725, 'lng': -122.3347265}                dentist
# 220         {'lat': 47.6127103, 'lng': -122.3366522}                dentist
# 221         {'lat': 47.6127103, 'lng': -122.3366522}                dentist
# 222         {'lat': 47.6127468, 'lng': -122.3365653}                dentist
# 223         {'lat': 47.6127103, 'lng': -122.3366522}                dentist
# 224          {'lat': 47.612706, 'lng': -122.3366129}                dentist
# 225         {'lat': 47.6127468, 'lng': -122.3365653}                dentist
# 226         {'lat': 47.6127103, 'lng': -122.3366522}                dentist
# 227          {'lat': 47.612697, 'lng': -122.3367849}                dentist
# 228         {'lat': 47.6127103, 'lng': -122.3366522}                dentist
# 229         {'lat': 47.6127103, 'lng': -122.3366522}                dentist
# 230          {'lat': 47.612706, 'lng': -122.3366129}                dentist
# 231          {'lat': 47.612764, 'lng': -122.3366957}                dentist
# 232         {'lat': 47.6264717, 'lng': -122.3298034}                 doctor
# 233         {'lat': 47.6264634, 'lng': -122.3298145}                 doctor
# 234         {'lat': 47.6264966, 'lng': -122.3297588}                 doctor
# 235         {'lat': 47.6264633, 'lng': -122.3298145}                 doctor
# 236         {'lat': 47.6128525, 'lng': -122.3363899}                 doctor
# 237          {'lat': 47.626458, 'lng': -122.3298046}                 doctor
# 238         {'lat': 47.6236533, 'lng': -122.3419756}                 doctor
# 239           {'lat': 47.626522, 'lng': -122.329567}                 doctor
# 240   {'lat': 47.62651999999999, 'lng': -122.329569}                 doctor
# 241  {'lat': 47.62645999999999, 'lng': -122.3298292}                 doctor
# 242         {'lat': 47.6127103, 'lng': -122.3366522}                 doctor
# 243          {'lat': 47.612697, 'lng': -122.3367849}                 doctor
# 244         {'lat': 47.6264718, 'lng': -122.3298034}                 doctor
# 245         {'lat': 47.6264718, 'lng': -122.3298034}                 doctor
# 246           {'lat': 47.632534, 'lng': -122.341274}                 doctor
# 247  {'lat': 47.63260269999999, 'lng': -122.3416975}                 doctor
# 248         {'lat': 47.6264718, 'lng': -122.3298034}                 doctor
# 249         {'lat': 47.6235008, 'lng': -122.3295425}                 doctor
# 250           {'lat': 47.6234827, 'lng': -122.32953}                 doctor
# 251         {'lat': 47.6160652, 'lng': -122.3348704}                 doctor
# 252          {'lat': 47.626458, 'lng': -122.3298046}               hospital
# 253         {'lat': 47.6127103, 'lng': -122.3366522}               hospital
# 254          {'lat': 47.633793, 'lng': -122.3407781}               hospital
# 255         {'lat': 47.6127468, 'lng': -122.3365653}               hospital
# 256         {'lat': 47.6342972, 'lng': -122.3395384}               hospital
# 257  {'lat': 47.62570050000001, 'lng': -122.3318162}               hospital
# 258         {'lat': 47.6152951, 'lng': -122.3484263}               hospital
# 259         {'lat': 47.6152951, 'lng': -122.3484263}               hospital
# 260         {'lat': 47.6127468, 'lng': -122.3365653}               hospital
# 261          {'lat': 47.612706, 'lng': -122.3366128}               hospital
# 262         {'lat': 47.6120914, 'lng': -122.3285955}               hospital
# 263         {'lat': 47.6114682, 'lng': -122.3438233}               hospital
# 264         {'lat': 47.6283846, 'lng': -122.3419538}               hospital
# 265          {'lat': 47.6288582, 'lng': -122.342925}               hospital
# 266  {'lat': 47.62648909999999, 'lng': -122.3307258}               hospital
# 267         {'lat': 47.6265715, 'lng': -122.3296862}               hospital
# 268         {'lat': 47.6327372, 'lng': -122.3402772}               hospital
# 269         {'lat': 47.6118868, 'lng': -122.3284883}               hospital
# 270         {'lat': 47.6196278, 'lng': -122.3571724}               hospital
# 271  {'lat': 47.61615020000001, 'lng': -122.3449657}           fire_station
# 272   {'lat': 47.63116099999999, 'lng': -122.354959}           fire_station
# 273         {'lat': 47.6285542, 'lng': -122.3398153}                airport
# 274          {'lat': 47.631846, 'lng': -122.3275375}                airport
# 275     {'lat': 47.61893999999999, 'lng': -122.3423}            bus_station
# 276  {'lat': 47.62133879999999, 'lng': -122.3474705}            bus_station
# 277         {'lat': 47.6214555, 'lng': -122.3477392}            bus_station
# 278          {'lat': 47.6171646, 'lng': -122.341743}            bus_station
# 279         {'lat': 47.6145493, 'lng': -122.3360078}            bus_station
# 280  {'lat': 47.61687189999999, 'lng': -122.3482876}            bus_station
# 281             {'lat': 47.61415, 'lng': -122.34173}            bus_station
# 282         {'lat': 47.6145292, 'lng': -122.3334163}            bus_station
# 283         {'lat': 47.6164755, 'lng': -122.3266867}            bus_station
# 284         {'lat': 47.6128246, 'lng': -122.3414248}            bus_station
# 285         {'lat': 47.6152891, 'lng': -122.3252144}            bus_station
# 286         {'lat': 47.6061389, 'lng': -122.3328481}               bus_stop
# 287         {'lat': 47.6205186, 'lng': -122.3426781}               bus_stop
# 288            {'lat': 47.62033, 'lng': -122.342822}               bus_stop
# 289         {'lat': 47.6249635, 'lng': -122.3447049}               bus_stop
# 290  {'lat': 47.62639619999999, 'lng': -122.3331541}               bus_stop
# 291         {'lat': 47.6204076, 'lng': -122.3446676}               bus_stop
# 292           {'lat': 47.618244, 'lng': -122.337408}               bus_stop
# 293  {'lat': 47.61805649999999, 'lng': -122.3398985}               bus_stop
# 294         {'lat': 47.6258293, 'lng': -122.3468997}               bus_stop
# 295  {'lat': 47.61554169999999, 'lng': -122.3418856}               bus_stop
# 296         {'lat': 47.6256677, 'lng': -122.3508744}               bus_stop
# 297          {'lat': 47.6297061, 'lng': -122.329046}               bus_stop
# 298  {'lat': 47.61428739999999, 'lng': -122.3367201}               bus_stop
# 299         {'lat': 47.6139253, 'lng': -122.3407168}               bus_stop
# 300         {'lat': 47.6136997, 'lng': -122.3381933}               bus_stop
# 301         {'lat': 47.6146282, 'lng': -122.3451633}               bus_stop
# 302         {'lat': 47.6138017, 'lng': -122.3341859}               bus_stop
# 303   {'lat': 47.61314999999999, 'lng': -122.333677}               bus_stop
# 304         {'lat': 47.6127521, 'lng': -122.3334516}               bus_stop
# 305         {'lat': 47.6050242, 'lng': -122.3343709}               bus_stop
# 306         {'lat': 47.6061389, 'lng': -122.3328481}  international_airport
# 307         {'lat': 47.6205186, 'lng': -122.3426781}  international_airport
# 308            {'lat': 47.62033, 'lng': -122.342822}  international_airport
# 309         {'lat': 47.6249635, 'lng': -122.3447049}  international_airport
# 310  {'lat': 47.62639619999999, 'lng': -122.3331541}  international_airport
# 311         {'lat': 47.6204076, 'lng': -122.3446676}  international_airport
# 312           {'lat': 47.618244, 'lng': -122.337408}  international_airport
# 313  {'lat': 47.61805649999999, 'lng': -122.3398985}  international_airport
# 314         {'lat': 47.6258293, 'lng': -122.3468997}  international_airport
# 315  {'lat': 47.61554169999999, 'lng': -122.3418856}  international_airport
# 316         {'lat': 47.6256677, 'lng': -122.3508744}  international_airport
# 317          {'lat': 47.6297061, 'lng': -122.329046}  international_airport
# 318  {'lat': 47.61428739999999, 'lng': -122.3367201}  international_airport
# 319         {'lat': 47.6139253, 'lng': -122.3407168}  international_airport
# 320         {'lat': 47.6136997, 'lng': -122.3381933}  international_airport
# 321         {'lat': 47.6146282, 'lng': -122.3451633}  international_airport
# 322         {'lat': 47.6138017, 'lng': -122.3341859}  international_airport
# 323   {'lat': 47.61314999999999, 'lng': -122.333677}  international_airport
# 324         {'lat': 47.6127521, 'lng': -122.3334516}  international_airport
# 325         {'lat': 47.6050242, 'lng': -122.3343709}  international_airport
# 326         {'lat': 47.6212828, 'lng': -122.3497545}        transit_station
# 327         {'lat': 47.6249256, 'lng': -122.3384705}        transit_station
# 328   {'lat': 47.62161449999999, 'lng': -122.338463}        transit_station
# 329    {'lat': 47.62524029999999, 'lng': -122.34235}        transit_station
# 330  {'lat': 47.62629440000001, 'lng': -122.3335734}        transit_station
# 331          {'lat': 47.6273231, 'lng': -122.342327}        transit_station
# 332   {'lat': 47.61853789999999, 'lng': -122.338623}        transit_station
# 333         {'lat': 47.6187782, 'lng': -122.3422315}        transit_station
# 334          {'lat': 47.6180306, 'lng': -122.338402}        transit_station
# 335          {'lat': 47.6273976, 'lng': -122.332577}        transit_station
# 336             {'lat': 47.6236, 'lng': -122.347569}        transit_station
# 337           {'lat': 47.621294, 'lng': -122.347599}        transit_station
# 338         {'lat': 47.6289006, 'lng': -122.3435285}        transit_station
# 339          {'lat': 47.6298714, 'lng': -122.340984}        transit_station
# 340   {'lat': 47.62904929999999, 'lng': -122.346226}        transit_station
# 341   {'lat': 47.61885830000001, 'lng': -122.347794}        transit_station
# 342          {'lat': 47.6152422, 'lng': -122.337835}        transit_station
# 343         {'lat': 47.6240668, 'lng': -122.3385861}        transit_station
# 344   {'lat': 47.62341689999999, 'lng': -122.337044}        transit_station
# 345             {'lat': 47.62185, 'lng': -122.33836}        transit_station

# %%
def get_distances(origin, destinations, api_key):
    url = "https://maps.googleapis.com/maps/api/distancematrix/json"
    params = {
        "origins": origin,
        "destinations": "|".join(destinations),
        "key": api_key
    }
    response = requests.get(url, params=params)
    data = response.json()
    return [element['distance']['value'] for element in data['rows'][0]['elements']]

def get_distance_between_locations(api_key, origin, destination):
    url = "https://maps.googleapis.com/maps/api/distancematrix/json"
    params = {
        "origins": origin,
        "destinations": destination,
        "key": api_key
    }
    response = requests.get(url, params=params)
    data = response.json()
    if data.get('status') == 'OK':
        distance = data['rows'][0]['elements'][0]['distance']['text']
        return distance
    else:
        return f"Error: {data.get('status')} - {data.get('error_message', 'No error message provided')}"

def rank_rentals(rentals, priorities, importance, location_data, api_key):

    weights = dict()
    for i in range(len(priorities)):
        weights[priorities[i]] = importance[i]


    for rental in rentals:
        origin = f"{rental['lat']},{rental['lng']}"
        distances = dict()
        for i in range(len(priorities)):
            distances[priorities[i]] = min(get_distances(origin, location_data[priorities[i]], api_key))
        rental['score'] = sum(weights[k] * (1 / v) for k, v in distances.items())
    
    return sorted(rentals, key=lambda x: x['score'], reverse=True)[:5]


# Example usage
rentals = [
    {'id': 1, 'lat': 47.622475, 'lng': -122.34279},  
    {'id': 2, 'lat': 47.635025, 'lng': -122.32449},
    {'id': 3, 'lat': 47.631638, 'lng': -122.3427},
    {'id': 4, 'lat': 47.621193, 'lng': -122.32755},
    {'id': 5, 'lat': 47.62591, 'lng': -122.32581} 
]

place_types = ['supermarket', 'school', 'park']
location_data = prepare_location_data(api_key, location, place_types)

importance = [0.5,0.3,0.2]
priorities = ['supermarket','school','park']
top_5_rentals = rank_rentals(rentals, priorities, importance, location_data, api_key)

# %%
def get_distances(origin, destinations, api_key):
    url = "https://maps.googleapis.com/maps/api/distancematrix/json"
    params = {
        "origins": origin,
        "destinations": "|".join(destinations),
        "key": api_key
    }
    response = requests.get(url, params=params)
    data = response.json()
    return [element['distance']['value'] for element in data['rows'][0]['elements']]

def rank_rentals(rentals, priorities, frequencies, location_data, api_key, buildings=None, building_freq=None):
    #frequencies is corresponding the number of trips made to a place in a week

    total_trips=sum(frequencies)
    building_importance=[]
    if building_freq: 
        total_trips+= sum(building_freq)
        building_importance=[0]*len(building_freq)
    importance = [0]*len(priorities)
    

    for i in range(len(frequencies)):
        importance[i] = frequencies[i]/total_trips
        
    if building_freq and buildings:
        for i in range(len(building_freq)):
            building_importance[i] = building_freq[i]/total_trips

    weights = dict()
    for i in range(len(priorities)):
        weights[priorities[i]] = importance[i]
    if buildings:
        for i in range(len(buildings)):
            weights[buildings[i]] = building_importance[i]


    for rental in rentals:
        origin = f"{rental['lat']},{rental['lng']}"
        distances = dict()
        for i in range(len(priorities)):
            distances[priorities[i]] = min(get_distances(origin, location_data[priorities[i]], api_key))

        if buildings and building_freq:
            for i in range(len(buildings)):
                distances[buildings[i]] = get_distance_between_locations(origin, f"{buildings[i]['lat']},{buildings[i]['lng']}")
        
        rental['score'] = sum(weights[k] * (1 / v) for k, v in distances.items())

    return sorted(rentals, key=lambda x: x['score'], reverse=True)[:5]


# Example usage
rentals = [
    {'id': 1, 'lat': 47.622475, 'lng': -122.34279},  
    {'id': 2, 'lat': 47.635025, 'lng': -122.32449},
    {'id': 3, 'lat': 47.631638, 'lng': -122.3427},
    {'id': 4, 'lat': 47.621193, 'lng': -122.32755},
    {'id': 5, 'lat': 47.62591, 'lng': -122.32581},
    {'id':6,'lat':47.62131,'lng':-122.32442}   
]

place_types = ['supermarket', 'school', 'park']
location_data = prepare_location_data(api_key, location, place_types)

frequencies = [2,5,4]
priorities = ['supermarket','school','park']
top_5_rentals = rank_rentals(rentals, priorities, frequencies, location_data, api_key)

# %%
top_5_rentals
# Out:
# [{'id': 4,
#   'lat': 47.621193,
#   'lng': -122.32755,
#   'score': 0.0042924130890069495},
#  {'id': 6, 'lat': 47.62131, 'lng': -122.32442, 'score': 0.003743373891506137},
#  {'id': 5, 'lat': 47.62591, 'lng': -122.32581, 'score': 0.003287562111091523},
#  {'id': 1,
#   'lat': 47.622475,
#   'lng': -122.34279,
#   'score': 0.0014788250948969495},
#  {'id': 2,
#   'lat': 47.635025,
#   'lng': -122.32449,
#   'score': 0.0009070562799950987}]
